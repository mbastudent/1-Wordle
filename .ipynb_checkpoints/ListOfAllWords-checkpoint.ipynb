# %%
"""
Contains sets of English words from svnweb.freebsd.org/csrg/share/dict/. This is up to date with revision 61569 of their words list.

There are four sets in this package:

english_words_set: A set of English words containing both upper- and lower-case letters; with punctuation.
english_words_lower_set: A set of English words containing lower-case letters; with punctuation.
english_words_alpha_set: A set of English words containing both upper- and lower-case letters; with no punctuation.
english_words_lower_alpha_set: A set of English words containing lower-case letters; with no punctuation.
where the lower set is the same as the english_words_set with all upper-case letters converted to lower-case letters, and where the alpha set is the same as the english_words_set with all apostrophes (') removed. The lower_alpha set intuitively has both of the rules from the lower set and the alpha set applied.

You can use use these like you would any Python set:

>>> from english_words import english_words_set
>>> 'ghost' in english_words_set

"""
import random
from english_words import english_words_lower_set


print(len(english_words_lower_set))


def random_word(words):
    upper = len(words)
    random_number = random.randint(1, upper)
    return words[random_number-1]


"""
def word_list():
    words_full_list = []
    with open("5_letter_words.txt", "r") as file:
        for line in file:
            line = line.strip()
            words_full_list.append(line)
    return words_full_list
    
    



def play():
    words_full_list = word_list()
    the_word = random_word(words_full_list)
    
    count = 1
    while count <= 6:
        print(count)
        guess_word = next_guess(words_full_list)
        
        icons = check_guess(guess_word, the_word)
        print(icons)
        
        if icons == "XXXXX":
            print("You won!")
            return True
        
        count += 1
    
    print("You lost!")
    print("The word was", the_word)
    return False
    
    
play()
"""
# Out:
# 25480
# {'vintner', 'daylight', 'wednesday', 'chalice', 'designate', 'time', 'ruin', 'increment', 'chipmunk', 'antelope', 'euphemist', 'phenomenal', 'earmark', 'greenberg', 'twinkle', 'rape', 'trauma', 'ascii', 'numerable', 'stockbroker', 'tina', 'gegenschein', 'screed', 'cigarette', 'copra', 'cribbage', 'millenia', 'oxnard', 'elizabeth', 'digestive', 'handspike', 'include', 'runge', 'penna', 'ginsberg', 'thorpe', 'waterman', 'nitpick', 'betroth', 'facto', 'imperfect', 'deny', 'anthropogenic', 'rosetta', 'coccidiosis', 'gospel', 'encumbrance', 'erie', 'check', 'kinesic', 'liverwort', 'gladden', 'hieratic', 'forfend', 'bruise', 'instantaneous', 'clinic', 'calendar', 'ail', 'hate', 'hummingbird', 'tatty', 'haplology', 'frederic', 'coalescent', 'snobbish', 'postgraduate', 'shack', 'synchronous', 'beguile', 'cotyledon', 'mandate', 'jury', 'malfunction', 'auditor', 'nourish', 'gnostic', 'bituminous', 'allegiant', 'transverse', 'temptation', 'ultimate', 'simpleton', 'garnish', 'formidable', 'hypertensive', 'influx', 'pin', 'enervate', 'tyranny', 'spillover', 'sag', 'venezuela', 'sprue', 'synapse', 'viola', 'goofy', 'bench', 'gnp', 'inlet', 'polaris', 'capella', 'balinese', 'ran', 'licensable', 'journeyman', 'bladdernut', 'strait', 'geopolitic', 'thermo', 'referenda', 'referring', 'combinatoric', 'chemise', 'slice', 'villain', 'degenerate', 'variant', 'wingbeat', 'rhodesia', 'walpole', 'tetragonal', 'bridgetown', 'erratic', 'pus', 'lush', 'knobby', 'rug', 'bookkeep', 'wart', 'backplane', 'dihedral', 'dillon', 'flatland', 'spit', 'glasswort', 'creak', 'none', 'aloft', 'ruanda', 'simile', 'sawfish', 'pizarro', 'berman', 'schlieren', 'crypto', 'erratum', 'teleology', 'affiliate', 'beget', 'fisticuff', 'work', 'airman', 'courthouse', 'reliant', 'horseman', 'insupportable', 'interstice', 'jarvin', 'marble', 'braniff', 'bulkhead', 'accede', 'incoherent', 'perquisite', 'ooze', 'genesis', 'argus', 'metabolite', 'crucifix', 'mine', 'schwartz', 'devonshire', 'brunswick', 'carr', 'comfort', 'shreveport', 'encryption', 'tiber', 'ourselves', 'top', 'lengthy', 'adverse', 'phrasemake', 'furze', 'tacky', 'centerline', 'export', 'forget', 'goucher', 'lemming', 'methyl', 'lumbermen', 'estuarine', 'insincere', 'whether', 'rhubarb', 'germane', 'prosopopoeia', 'blight', 'botany', 'az', 'cohomology', 'lucy', 'scripps', 'hagiography', 'sake', 'anthracite', 'viscera', 'melodic', 'interdigitate', 'caw', 'filet', 'crosby', 'insistent', 'thalia', 'electrolyte', 'fete', 'brainstorm', 'hangable', 'arhat', 'glen', 'regime', 'centrist', 'paz', 'obsequy', 'momentum', 'rotenone', 'astigmat', 'groton', 'can', 'nectarine', 'pond', 'cutler', 'hurd', 'feudal', 'icebox', 'charleston', 'wong', 'impermissible', 'termini', 'gautama', 'tokamak', 'cashew', 'vitro', 'tying', 'memoir', 'huston', 'suppressible', 'metabolism', 'therefrom', 'dashboard', 'barton', 'scarecrow', 'virus', 'corundum', 'hydroxyl', 'prevention', 'britain', "that'll", 'cancelled', 'wakefield', 'vestige', 'carpentry', 'satisfy', 'crumble', 'parvenu', 'christoph', 'draconian', 'plank', 'tress', 'crappie', 'boa', 'comic', 'camille', 'sunburn', 'norwich', 'gyrocompass', 'hindrance', 'husbandry', 'delete', 'possessor', 'tommie', 'manometer', 'raindrop', 'twain', 'siege', 'invidious', 'plaintive', 'pierson', 'corroboree', 'dieldrin', 'cowbird', 'assuage', 'linseed', 'johanson', 'crepe', 'romania', 'hopscotch', 'mathias', 'passport', 'oakland', 'nephew', 'barracuda', 'feathertop', 'mortgage', 'deceptive', 'pulse', 'polecat', 'chromatograph', 'unanimous', 'zimmerman', 'stooge', 'midwestern', 'rod', 'idyllic', 'lineage', 'jealous', 'pancreas', 'fragmentary', 'frighten', 'sanguineous', 'courtyard', 'moravia', 'gun', 'clapboard', 'marlboro', 'phd', 'tram', 'nuthatch', 'taipei', 'coup', 'malcontent', 'warp', 'homeopath', 'aniseikonic', 'nor', 'praline', 'gilmore', 'atom', 'apparatus', 'gustafson', 'contributory', 'en', 'carboloy', 'famous', 'therapy', 'by', 'deportee', 'leachate', 'nudge', 'breed', 'southward', 'fivefold', ' ...
# '\ndef word_list():\n    words_full_list = []\n    with open("5_letter_words.txt", "r") as file:\n        for line in file:\n            line = line.strip()\n            words_full_list.append(line)\n    return words_full_list\n    \n    \ndef random_word(words):\n    upper = len(words)\n    random_number = random.randint(1, upper)\n    return words[random_number-1]\n\n\ndef play():\n    words_full_list = word_list()\n    the_word = random_word(words_full_list)\n    \n    count = 1\n    while count <= 6:\n        print(count)\n        guess_word = next_guess(words_full_list)\n        \n        icons = check_guess(guess_word, the_word)\n        print(icons)\n        \n        if icons == "XXXXX":\n            print("You won!")\n            return True\n        \n        count += 1\n    \n    print("You lost!")\n    print("The word was", the_word)\n    return False\n    \n    \nplay()\n'
